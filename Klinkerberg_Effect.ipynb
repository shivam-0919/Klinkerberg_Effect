# %% [markdown]
# <a href="https://colab.research.google.com/github/shivam-0919/Klinkerberg_Effect/blob/main/Klinkerberg_Effect.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
k = input("\nEnter your first guess of absolute permeability kl: ")

k = float(k)

#f(k = kl) = 6.9kL^(0.64) + pmkL - pm*kg = 0
# f'(k) = 4.416 ki^(-0.36) + pm

pm  = input("\nEnter Mean Pr. Pm: ")
pm = float(pm)

kg = input("\nEnter K(air) = kg: ")
kg = float(kg)

while abs(6.9*(k**0.64) + pm*k - pm*kg) > 0.001:
  k = k - (6.9*(k**0.64) + pm*k - pm*kg)/(4.416*(k**(-0.36)) + pm)

print(f"The final value of Perm K is : {k}")
# Out:
# Enter your first guess of absolute permeability kl: 50
#
# Enter Mean Pr. Pm: 2.152
#
# Enter K(air) = kg: 46.6
# The final value of Perm K is : 22.84900220489256
